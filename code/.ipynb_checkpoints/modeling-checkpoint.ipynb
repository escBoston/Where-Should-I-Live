# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score, r2_score
from sklearn.decomposition import PCA

import requests
from bs4 import BeautifulSoup

import pickle
import time

# %%
testinc = pd.read_csv('../data/testinc.csv')

# %% [markdown]
# ### Modeling

# %% [markdown]
# ### K Means Clustering

# %%
testinc.head()
# Out:
#    Unnamed: 0                  townstate  poverty  med_income  hs_completion  \
# 0           0         Abbeville, Alabama     20.7     40186.0           79.1
# 1           1       Abbeville, Louisiana     31.5     47483.0           70.7
# 2           2  Abbeville, South Carolina     39.9     34292.0           75.3
# 3           3            Aberdeen, Idaho     13.8     43793.0           61.3
# 4           4         Aberdeen, Maryland     17.2     60489.0           88.0
#
#    n_households  population  density  crime_rate  property_crime  \
# 0          2555        6055     12.2        62.0            51.0
# 1          9292       25897     42.4       591.0           474.0
# 2          4925       13006     19.9       229.0           199.0
# 3          1127        3533      5.0        22.0            21.0
# 4          9538       24453    277.6       330.0           251.0
#
#    violent_crime  students_per_teacher     gini       lat        lng  \
# 0           11.0             13.000000  0.46135  31.60296  -85.21630
# 1          117.0             14.875000  0.46135  29.89813  -92.19967
# 2           30.0             14.600000  0.46135  34.17875  -82.42871
# 3            1.0             20.000000  0.46135  43.01939 -112.86185
# 4           79.0             12.285714  0.41070  39.51075  -76.20061
#
#    unemployment_rate  home_price  crime_rate_pc  vcrime_rate_pc  \
# 0            4.58761     86264.0       0.010239        0.001817
# 1            4.58761    129370.0       0.022821        0.004518
# 2            4.58761    128638.0       0.017607        0.002307
# 3            4.58761    128794.0       0.006227        0.000283
# 4            3.70000    213991.0       0.013495        0.003231
#
#    pcrime_rate_pc  people_per_household           state
# 0        0.008423              2.369863         Alabama
# 1        0.018303              2.787021       Louisiana
# 2        0.015301              2.640812  South Carolina
# 3        0.005944              3.134871           Idaho
# 4        0.010265              2.563745        Maryland

# %%
testinc['log_density'] = np.log(testinc['density'])

# %%
features = [
    'med_income',
    'poverty',
    'hs_completion',
    'population',
    'density',
    #'log_density',
    'students_per_teacher',
    'gini',
    'crime_rate',
    'crime_rate_pc',
    'property_crime',
    'violent_crime',
    'unemployment_rate',
    'home_price'
]
X = testinc[features].copy()

# %%
X.corr()
# Out:
#                       med_income   poverty  hs_completion  population  \
# med_income              1.000000 -0.667322       0.521329    0.327548
# poverty                -0.667322  1.000000      -0.596651   -0.140142
# hs_completion           0.521329 -0.596651       1.000000    0.152299
# population              0.327548 -0.140142       0.152299    1.000000
# density                 0.226592 -0.140821       0.066058    0.287677
# students_per_teacher    0.105823 -0.056780       0.048625    0.111295
# gini                   -0.122268  0.147579      -0.092610   -0.062801
# crime_rate              0.135994 -0.026673       0.072495    0.655655
# crime_rate_pc          -0.094674  0.080495      -0.022981    0.039584
# property_crime          0.154220 -0.045737       0.093543    0.653115
# violent_crime          -0.007289  0.093062      -0.070927    0.499741
# unemployment_rate      -0.217877  0.201973      -0.204912   -0.061357
# home_price              0.715272 -0.357620       0.295034    0.234210
#
#                        density  students_per_teacher      gini  crime_rate  \
# med_income            0.226592              0.105823 -0.122268    0.135994
# poverty              -0.140821             -0.056780  0.147579   -0.026673
# hs_completion         0.066058              0.048625 -0.092610    0.072495
# population            0.287677              0.111295 -0.062801    0.655655
# density               1.000000              0.071847  0.135645    0.301118
# students_per_teacher  0.071847              1.000000 -0.030480    0.120092
# gini                  0.135645             -0.030480  1.000000   -0.011981
# crime_rate            0.301118              0.120092 -0.011981    1.000000
# crime_rate_pc         0.123181              0.052545  0.028268    0.531496
# property_crime        0.290070              0.122078 -0.023485    0.994242
# violent_crime         0.287974              0.077034  0.059198    0.773357
# unemployment_rate    -0.000372              0.039557  0.265483    0.022658
# home_price            0.284547              0.149454  0.014598    0.175484
#
#                       crime_rate_pc  property_crime  violent_crime  \
# med_income                -0.094674        0.154220      -0.007289
# poverty                    0.080495       -0.045737       0.093062
# hs_completion             -0.022981        0.093543      -0.070927
# population                 0.039584        0.653115       0.499741
# density                    0.123181        0.290070       0.287974
# students_per_teacher       0.052545        0.122078       0.077034
# gini                       0.028268       -0.023485       0.059198
# crime_rate                 0.531496        0.994242       0.773357
# crime_rate_pc              1.000000        0.530966       0.396069
# property_crime             0.530966        1.000000       0.700967
# violent_crime              0.396069        0.700967       1.000000
# unemployment_rate          0.073090        0.009939       0.091997
# home_price                 0.025619        0.186891       0.062254
#
#                       unemployment_rate  home_price
# med_income                    -0.217877    0.715272
# poverty                        0.201973   -0.357620
# hs_completion                 -0.204912    0.295034
# population                    -0.061357    0.234210
# density                       -0.000372    0.284547
# students_per_teacher           0.039557    0.149454
# gini                           0.265483    0.014598
# crime_rate                     0.022658    0.175484
# crime_rate_pc                  0.073090    0.025619
# property_crime                 0.009939    0.186891
# violent_crime                  0.091997    0.062254
# unemployment_rate              1.000000   -0.111253
# home_price                    -0.111253    1.000000

# %%
ss = StandardScaler()
X_scaled = ss.fit_transform(X)

# %%
km = KMeans(n_clusters = 2, random_state = 42)

# %%
km.fit(X_scaled)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=42, tol=0.0001, verbose=0)

# %%
testinc['cluster'] = km.labels_

# %%
centroids = testinc.groupby('cluster')[features].mean()
centroids
# Out:
#            med_income    poverty  hs_completion    population     density  \
# cluster
# 0        50018.115227  18.981938      84.389956   8824.223822   75.344620
# 1        61991.280366  16.322763      87.417151  35107.669545  537.095928
#
#          students_per_teacher      gini  crime_rate  crime_rate_pc  \
# cluster
# 0                   15.090822  0.457210   94.013424        0.01075
# 1                   17.466040  0.455882  609.233909        0.02353
#
#          property_crime  violent_crime  unemployment_rate     home_price
# cluster
# 0             83.845741      10.167684           4.561231  151069.111159
# 1            541.410518      67.823391           4.522725  287656.558485

# %%
ss.inverse_transform(km.cluster_centers_)
# Out:
# array([[5.00181152e+04, 1.89819380e+01, 8.43899561e+01, 8.82422382e+03,
#         7.53446200e+01, 1.50908222e+01, 4.57210426e-01, 9.40134245e+01,
#         1.07496417e-02, 8.38457408e+01, 1.01676837e+01, 4.56123069e+00,
#         1.51069111e+05],
#        [6.19912804e+04, 1.63227630e+01, 8.74171507e+01, 3.51076695e+04,
#         5.37095928e+02, 1.74660399e+01, 4.55881918e-01, 6.09233909e+02,
#         2.35303618e-02, 5.41410518e+02, 6.78233909e+01, 4.52272463e+00,
#         2.87656558e+05]])

# %%
colors = ['red', 'green']
testinc['color'] = testinc['cluster'].map(lambda p: colors[p])

axis_1 = 'hs_completion'
axis_2 = 'density'

ax = testinc.plot(    
    kind = 'scatter', 
    x = axis_1, y = axis_2,
    figsize = (10,8),
    alpha = .5,
    c = testinc['color']
)

centroids.plot(
    kind = 'scatter', 
    x = axis_1, y = axis_2, 
    marker = '*', c = 'yellow', s = 550,
    ax = ax
);

# %%
silhouette_score(X_scaled, km.labels_)
# Out:
# 0.36337632899453304

# %%
scores = []
for k in range(2, 30):
    cl = KMeans(n_clusters = k, random_state = 42)
    cl.fit(X_scaled)
    inertia = cl.inertia_
    sil = silhouette_score(X_scaled, cl.labels_)
    scores.append((k, inertia, sil))

# %%
score_df = pd.DataFrame(scores, columns = ['k', 'inertia', 'sil'])
score_df.head()
# Out:
#    k       inertia       sil
# 0  2  55414.006188  0.363376
# 1  3  49229.350610  0.184653
# 2  4  44994.607122  0.171310
# 3  5  41800.322747  0.172641
# 4  6  39859.293797  0.171408

# %% [markdown]
# ### Regression

# %%
pd.set_option('display.max_columns', 35)
testinc.head()
# Out:
#    Unnamed: 0                  townstate  poverty  med_income  hs_completion  \
# 0           0         Abbeville, Alabama     20.7     40186.0           79.1
# 1           1       Abbeville, Louisiana     31.5     47483.0           70.7
# 2           2  Abbeville, South Carolina     39.9     34292.0           75.3
# 3           3            Aberdeen, Idaho     13.8     43793.0           61.3
# 4           4         Aberdeen, Maryland     17.2     60489.0           88.0
#
#    n_households  population  density  crime_rate  property_crime  \
# 0          2555        6055     12.2        62.0            51.0
# 1          9292       25897     42.4       591.0           474.0
# 2          4925       13006     19.9       229.0           199.0
# 3          1127        3533      5.0        22.0            21.0
# 4          9538       24453    277.6       330.0           251.0
#
#    violent_crime  students_per_teacher     gini       lat        lng  \
# 0           11.0             13.000000  0.46135  31.60296  -85.21630
# 1          117.0             14.875000  0.46135  29.89813  -92.19967
# 2           30.0             14.600000  0.46135  34.17875  -82.42871
# 3            1.0             20.000000  0.46135  43.01939 -112.86185
# 4           79.0             12.285714  0.41070  39.51075  -76.20061
#
#    unemployment_rate  home_price  crime_rate_pc  vcrime_rate_pc  \
# 0            4.58761     86264.0       0.010239        0.001817
# 1            4.58761    129370.0       0.022821        0.004518
# 2            4.58761    128638.0       0.017607        0.002307
# 3            4.58761    128794.0       0.006227        0.000283
# 4            3.70000    213991.0       0.013495        0.003231
#
#    pcrime_rate_pc  people_per_household           state
# 0        0.008423              2.369863         Alabama
# 1        0.018303              2.787021       Louisiana
# 2        0.015301              2.640812  South Carolina
# 3        0.005944              3.134871           Idaho
# 4        0.010265              2.563745        Maryland

# %%
features = [
    'med_income',
    'poverty',
    'hs_completion',
    'density',
    'population',
    'students_per_teacher',
    'people_per_household',
    'lat',
    'lng',
    'crime_rate',
    'crime_rate_pc',
    'unemployment_rate',
    'gini',
]
X = testinc[features]
y = np.log(testinc['home_price'])

# %%
# pf = PolynomialFeatures()
# X_poly = pf.fit_transform(X)
X_poly = X.copy()

# %%
ss = StandardScaler()
X_scaled = ss.fit_transform(X_poly)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, random_state = 42)

# %%
rf = RandomForestRegressor(max_depth = 8, n_estimators = 25, random_state = 4)
rf.fit(X_train, y_train)
#rf.score(X_test, y_test)
pred = np.exp(rf.predict(X_test))
r2_score(np.exp(y_test), pred)
# Out:
# 0.8757704909777734

# %%
### Feature importance ###
# Residuals, missing data
# Feature relationships (student ratio is proxy for density?), education proxy for income?
# Joining data sources
# Ratio of crime types
# Under budget police towns have big erros
# Can model fill in blanks for places with non reported crimes?

# %%
pd.Series(rf.feature_importances_, features).sort_values()
# Out:
# population              0.005210
# unemployment_rate       0.005683
# crime_rate              0.006025
# students_per_teacher    0.006471
# gini                    0.012748
# crime_rate_pc           0.014793
# hs_completion           0.014828
# people_per_household    0.019038
# poverty                 0.019497
# density                 0.021770
# lat                     0.037102
# lng                     0.170921
# med_income              0.665913
# dtype: float64

# %%
results = pd.DataFrame({
    "pred": rf.predict(X_test),
    "actual": y_test
})
results['pred'] = np.log(results['pred'])
results['actual'] = np.log(results['actual'])
results.plot(kind='scatter', x='pred', y='actual')

# %%
residuals = []
for i in range(len(pred)):
    residuals.append(pred[i] - np.exp(y_test).iloc[i])

# %%
np.mean(residuals)
# Out:
# -4913.444438371449

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
lr.score(X_train, y_train), lr.score(X_test, y_test)
pred = np.exp(lr.predict(X_test))
r2_score(np.exp(y_test), pred)
# Out:
# -0.23372337808457266

# %%
cross_val_score(rf, X, y, cv = 5)
# Out:
# array([0.78370535, 0.77295984, 0.79287115, 0.82177703, 0.78070575])

# %%
lr.coef_
# Out:
# array([ 0.36920365, -0.00608566,  0.04209934,  0.09325613,  0.0302751 ,
#         0.0274148 , -0.03668776, -0.01504098, -0.15433573,  0.06128393,
#        -0.0297573 , -0.01025537, -0.01853843])

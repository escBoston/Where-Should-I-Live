# %% [markdown]
# population by town <br>
# https://www.census.gov/data/tables/time-series/demo/popest/2010s-total-cities-and-towns.html <br>
# cost of living by town <br>
# https://www.cityrating.com/costofliving.asp <br>
# crime stats by town <br>
# https://www.cityrating.com/crime-statistics/ <br>
# income, education, age data by town <br>
# https://factfinder.census.gov/faces/nav/jsf/pages/community_facts.xhtml

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import requests
from bs4 import BeautifulSoup

# %%
nypop = pd.read_csv('./data/pop/nypop.csv')

# %%
nypop.head()
# Out:
#              GEO.id  GEO.id2          GEO.display-label  \
# 0                Id      Id2                  Geography
# 1  1620000US3600199  3600199    Adams village, New York
# 2  1620000US3600276  3600276  Addison village, New York
# 3  1620000US3600342  3600342    Afton village, New York
# 4  1620000US3600408  3600408  Airmont village, New York
#
#               rescen42010                    resbase42010  \
# 0  April 1, 2010 - Census  April 1, 2010 - Estimates Base
# 1                    1775                            1784
# 2                    1763                            1763
# 3                     822                             835
# 4                    8628                            8625
#
#                                  respop72010  \
# 0  Population Estimate (as of July 1) - 2010
# 1                                       1791
# 2                                       1762
# 3                                        833
# ...

# %%
nypop.dtypes
# Out:
# GEO.id               object
# GEO.id2              object
# GEO.display-label    object
# rescen42010          object
# resbase42010         object
# respop72010          object
# respop72011          object
# respop72012          object
# respop72013          object
# respop72014          object
# respop72015          object
# respop72016          object
# respop72017          object
# respop72018          object
# dtype: object

# %%
url = 'https://www.cityrating.com/crime-statistics/new-york/adams-village.html'
res = requests.get(url)

# %%
soup = BeautifulSoup(res.content, 'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Adams Village Crime Statistics: New York (NY) - CityRating.com
#   </title>
#   <meta content="Adams Village crime statistics, Adams Village crime rate, violent crime, property crime, crime, assault, rape, car theft, burglary, arson, theft, larceny, Adams Village, New York, NY" name="keywords"/>
#   <meta content="Adams Village crime statistics including violent and property crime rates, with murder, rape, assault, arson, larceny, burglary and car theft data reports. Adams Village, New York crime report (NY)." name="description"/>
#   <meta content="https://www.cityrating.com/images/cityrating-square.png" property="og:image"/>
#   <meta content="width=device-width; initial-scale=1; maximum-scale=1" name="viewport"/>
#   <link href="/style/bootstrap.css" rel="stylesheet"/>
#  </head>
#  <body>
#   <script>
#    (function (i, s, o, g, r, a, m) {
# ...

# %%
soup.find_all('td')
# Out:
# [<td class="key">Aggravated Assault</td>,
#  <td class="value">0</td>,
#  <td class="key">Arson</td>,
#  <td class="value">0</td>,
#  <td class="key">Burglary</td>,
#  <td class="value">0</td>,
#  <td class="key">Larceny and Theft</td>,
#  <td class="value">3</td>,
#  <td class="key">Motor Vehicle Theft</td>,
#  <td class="value">1</td>,
#  <td class="key">Murder and Manslaughter</td>,
#  <td class="value">0</td>,
#  <td class="key">Rape</td>,
#  <td class="value">N/A</td>,
#  <td class="key">Robbery</td>,
#  <td class="value">0</td>,
#  <td class="key"><span class="total">Crime Rate</span> (Total Incidents)</td>,
#  <td class="value">4</td>,
#  <td class="key"><span class="total">Property Crime</span></td>,
#  <td class="value">4</td>,
#  <td class="key"><span class="total">Violent Crime</span></td>,
#  <td class="value">0</td>,
#  <td class="key">Aggravated Assault</td>,
#  <td class="value">0</td>,
#  <td class="key">Arson</td>,
#  <td class="value">0</td>,
# ...

# %%
soup.find_all('th', {'text' == '2016 Crime (Actual Data)*'})
# Out:
# []

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score, r2_score
from sklearn.decomposition import PCA

import requests
from bs4 import BeautifulSoup

import pickle
import time

# %%
testinc = pd.read_csv('./data/testinc.csv')

# %% [markdown]
# ### Modeling

# %% [markdown]
# ### K Means Clustering

# %%
testinc['log_density'] = np.log(testinc['density'])

# %%
features = [
    'med_income',
    'poverty',
    'hs_completion',
    # 'density',
    'log_density',
    'students_per_teacher',
    'gini',
    'crime_rate_pc',
    'property_crime',
    'violent_crime',
]
X = testinc[features].copy()

# %%
X.corr()
# Out:
#                       med_income   poverty  hs_completion  log_density  \
# med_income              1.000000 -0.667322       0.521329     0.418535
# poverty                -0.667322  1.000000      -0.596651    -0.260481
# hs_completion           0.521329 -0.596651       1.000000     0.233868
# log_density             0.418535 -0.260481       0.233868     1.000000
# students_per_teacher    0.105823 -0.056780       0.048625     0.179708
# gini                   -0.122268  0.147579      -0.092610    -0.021409
# crime_rate_pc          -0.094674  0.080495      -0.022981     0.215947
# property_crime          0.154220 -0.045737       0.093543     0.521649
# violent_crime          -0.007289  0.093062      -0.070927     0.378355
#
#                       students_per_teacher      gini  crime_rate_pc  \
# med_income                        0.105823 -0.122268      -0.094674
# poverty                          -0.056780  0.147579       0.080495
# hs_completion                     0.048625 -0.092610      -0.022981
# log_density                       0.179708 -0.021409       0.215947
# students_per_teacher              1.000000 -0.030480       0.052545
# gini                             -0.030480  1.000000       0.028268
# crime_rate_pc                     0.052545  0.028268       1.000000
# property_crime                    0.122078 -0.023485       0.530966
# violent_crime                     0.077034  0.059198       0.396069
#
#                       property_crime  violent_crime
# med_income                  0.154220      -0.007289
# poverty                    -0.045737       0.093062
# hs_completion               0.093543      -0.070927
# log_density                 0.521649       0.378355
# students_per_teacher        0.122078       0.077034
# gini                       -0.023485       0.059198
# crime_rate_pc               0.530966       0.396069
# property_crime              1.000000       0.700967
# violent_crime               0.700967       1.000000

# %%
ss = StandardScaler()
X_scaled = ss.fit_transform(X)

# %%
km = KMeans(n_clusters = 2, random_state = 42)

# %%
km.fit(X_scaled)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=42, tol=0.0001, verbose=0)

# %%
testinc['cluster'] = km.labels_

# %%
centroids = testinc.groupby('cluster')[features].mean()
centroids
# Out:
#            med_income    poverty  hs_completion  log_density  \
# cluster
# 0        65251.125884  13.874785      89.105323     5.287262
# 1        46883.938286  20.509092      83.181043     2.942567
#
#          students_per_teacher      gini  crime_rate_pc  property_crime  \
# cluster
# 0                   17.448665  0.453758       0.020717      429.130509
# 1                   14.789188  0.458408       0.010438       78.251104
#
#          violent_crime
# cluster
# 0            52.522610
# 1            10.018488

# %%
ss.inverse_transform(km.cluster_centers_)
# Out:
# array([[6.52511259e+04, 1.38747853e+01, 8.91053234e+01, 5.28726202e+00,
#         1.74486651e+01, 4.53757504e-01, 2.07167115e-02, 4.29130509e+02,
#         5.25226102e+01],
#        [4.68839383e+04, 2.05090922e+01, 8.31810430e+01, 2.94256652e+00,
#         1.47891875e+01, 4.58407925e-01, 1.04378775e-02, 7.82511038e+01,
#         1.00184879e+01]])

# %%
colors = ['red', 'green']
testinc['color'] = testinc['cluster'].map(lambda p: colors[p])

axis_1 = 'hs_completion'
axis_2 = 'log_density'

ax = testinc.plot(    
    kind = 'scatter', 
    x = axis_1, y = axis_2,
    figsize = (10,8),
    alpha = .5,
    c = testinc['color']
)

centroids.plot(
    kind = 'scatter', 
    x = axis_1, y = axis_2, 
    marker = '*', c = 'yellow', s = 550,
    ax = ax
);

# %%
silhouette_score(X_scaled, km.labels_)
# Out:
# 0.28156104343428595

# %%
scores = []
for k in range(2, 30):
    cl = KMeans(n_clusters = k, random_state = 42)
    cl.fit(X_scaled)
    inertia = cl.inertia_
    sil = silhouette_score(X_scaled, cl.labels_)
    scores.append((k, inertia, sil))

# %%
score_df = pd.DataFrame(scores, columns = ['k', 'inertia', 'sil'])
score_df.head()
# Out:
#    k       inertia       sil
# 0  2  38604.309601  0.281561
# 1  3  32879.081815  0.235993
# 2  4  29620.904791  0.182244
# 3  5  26431.113313  0.183142
# 4  6  24272.466977  0.195331

# %% [markdown]
# ### Regression

# %%
features = [
    'med_income',
    'poverty',
    'hs_completion',
    'density',
    'students_per_teacher',
    'people_per_household',
    'lat',
    'lng',
    'gini',
]
X = testinc[features]
y = testinc['crime_rate_pc']

# %%
# pf = PolynomialFeatures()
# X_poly = pf.fit_transform(X)
X_poly = X.copy()

# %%
ss = StandardScaler()
X_scaled = ss.fit_transform(X_poly)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, random_state = 42)

# %%
rf = RandomForestRegressor(max_depth = 8, n_estimators = 25, random_state=1) # random_state = 27
rf.fit(X_train, y_train)
pred = np.exp(rf.predict(X_test))
r2_score(np.exp(y_test), pred)
# Out:
# 0.1236810128761392

# %%
### Feature importance ###
# Residuals, missing data
# Feature relationships (student ratio is proxy for density?), education proxy for income?
# Joining data sources
# Ratio of crime types
# Under budget police towns have big erros
# Can model fill in blanks for places with non reported crimes?

# %%
pd.Series(rf.feature_importances_, features).sort_values()
# Out:
# gini                    0.046879
# students_per_teacher    0.053758
# poverty                 0.067412
# hs_completion           0.070577
# people_per_household    0.086590
# lat                     0.092121
# lng                     0.160496
# density                 0.210931
# med_income              0.211235
# dtype: float64

# %%
results = pd.DataFrame({
    "pred": rf.predict(X_test),
    "actual": y_test
})
results['pred'] = np.log(results['pred'])
results['actual'] = np.log(results['actual'])
results.plot(kind='scatter', x='pred', y='actual')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py:856: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
lr.score(X_test, y_test)
# Out:
# -0.23437632567168176

# %%
lr.coef_
# Out:
# array([-0.0018818 ,  0.00081515,  0.00120547,  0.00192466,  0.00054054,
#        -0.00277891, -0.00141359, -0.00176879, -0.00017611])
